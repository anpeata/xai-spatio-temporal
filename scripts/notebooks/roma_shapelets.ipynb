# %% [markdown]
# # Roma Taxi Shapelet Clustering (Temporal Features Only)

# %% [markdown]
# ## Overview\n\nThis notebook compares mixed-length vs fixed-length shapelets on temporal features for Roma taxi clustering.

# %%
import numpy as np\nimport pandas as pd\n# Temporal shapelet clustering analysis
