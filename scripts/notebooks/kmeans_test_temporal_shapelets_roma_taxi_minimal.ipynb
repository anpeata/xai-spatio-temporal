# %% [markdown]
# # Roma Taxi Shapelet Clustering (Temporal Features Only)
#
# Compare fixed-length and mixed-length shapelet profiles for clustering Roma taxi temporal windows.
#
# ## Key Finding (Current Reduced Run)
# In this reduced notebook run, the fixed-length profile `(3,)` outperformed mixed-length `(2,3,4)` (0.6910 vs 0.3380 average silhouette/composite). Treat this as run-specific evidence tied to the current sampling and candidate budget.
